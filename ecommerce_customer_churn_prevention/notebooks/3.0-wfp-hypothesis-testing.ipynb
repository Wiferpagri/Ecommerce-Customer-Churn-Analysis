# %% [markdown]
# # Hypothesis testing
#
# In statistics, is not enough with exploring the data visually, but it's necessary to make statistical test over them to confirm or negate our hypotheses. In this case, we gonna focus on non-parametric statistical tests, such as Kruskal-Wallis and Chi-Square tests, to test the relationship between the numerical and categorical variables with our objective variable.

# %% [markdown]
# # Preparing the environment

# %%
import pandas as pd
import sys
sys.path.append('../ecommerce_customer_churn_prevention')
from utils import paths, hypothesis_testing

# %% [markdown]
# # Importing the data

# %%
df = pd.read_csv(paths.data_interim_dir('df_etl_processed.csv'))
df.head()
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN         Mobile Phone         1              8.0
# 2       50003      1     NaN         Mobile Phone         1             30.0
# 3       50004      1     0.0         Mobile Phone         3             15.0
# 4       50005      1     0.0         Mobile Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4          Credit Card    Male             NaN                         3
#
#      PreferedOrderCat  SatisfactionScore MaritalStatus  NumberOfAddress  \
# 0  Laptop & Accessory                  2        Single                9
# 1        Mobile Phone                  3        Single                7
# 2        Mobile Phone                  3        Single                6
# 3  Laptop & Accessory                  5        Single                8
# 4        Mobile Phone                  5        Single                3
#
#    Complain  OrderAmountHikeFromlastYear  CouponUsed  OrderCount  \
# 0         1                         11.0         1.0         1.0
# 1         1                         15.0         0.0         1.0
# 2         1                         14.0         0.0         1.0
# 3         0                         23.0         0.0         1.0
# 4         0                         11.0         1.0         1.0
#
#    DaySinceLastOrder  CashbackAmount
# 0                5.0          159.93
# 1                0.0          120.90
# 2                3.0          120.28
# 3                3.0          134.07
# 4                3.0          129.60

# %%
# Converting the features to categorical like the data dictionary

cat_features = ['PreferredLoginDevice', 'CityTier', 'PreferredPaymentMode', 'Gender', 'PreferedOrderCat', 'MaritalStatus', 'Complain']
num_features = [col for col in df.columns if col not in cat_features]
num_features.remove('Churn')
num_features.remove('CustomerID')

df[cat_features] = df[cat_features].astype('category')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5630 entries, 0 to 5629
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CustomerID                   5630 non-null   int64
#  1   Churn                        5630 non-null   int64
#  2   Tenure                       5366 non-null   float64
#  3   PreferredLoginDevice         5630 non-null   category
#  4   CityTier                     5630 non-null   category
#  5   WarehouseToHome              5379 non-null   float64
#  6   PreferredPaymentMode         5630 non-null   category
#  7   Gender                       5630 non-null   category
#  8   HourSpendOnApp               5375 non-null   float64
#  9   NumberOfDeviceRegistered     5630 non-null   int64
#  10  PreferedOrderCat             5630 non-null   category
#  11  SatisfactionScore            5630 non-null   int64
#  12  MaritalStatus                5630 non-null   category
#  13  NumberOfAddress              5630 non-null   int64
#  14  Complain                     5630 non-null   category
#  15  OrderAmountHikeFromlastYear  5365 non-null   float64
#  16  CouponUsed                   5374 non-null   float64
#  17  OrderCount                   5372 non-null   float64
#  18  DaySinceLastOrder            5323 non-null   float64
#  19  CashbackAmount               5630 non-null   float64
# dtypes: category(7), float64(8), int64(5)
# memory usage: 611.4 KB

# %% [markdown]
# # Applying hypothesis testing

# %%
sig_cols = []
no_sig_cols = []
for col in cat_features:
    hypothesis_testing.chi2_independence_test(df, 'Churn', col, sig_col=sig_cols, no_sig_col=no_sig_cols)
# Out:
# --------------------------------------------------------------------------------
#                  test    lambda       chi2  dof      pval    cramer     power
# 0             pearson  1.000000  14.401253  1.0  0.000148  0.050576  0.966742
# 1        cressie-read  0.666667  14.278441  1.0  0.000158  0.050360  0.965523
# 2      log-likelihood  0.000000  14.046652  1.0  0.000178  0.049950  0.963106
# 3       freeman-tukey -0.500000  13.884409  1.0  0.000194  0.049660  0.961320
# 4  mod-log-likelihood -1.000000  13.731654  1.0  0.000211  0.049386  0.959565
# 5              neyman -2.000000  13.453089  1.0  0.000245  0.048883  0.956171
# Reject null hypothesis: There is a statistically significant difference between PreferredLoginDevice and Churn
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#                  test    lambda       chi2  dof          pval    cramer  \
# 0             pearson  1.000000  40.982404  2.0  1.261200e-09  0.085319
# 1        cressie-read  0.666667  40.590081  2.0  1.534532e-09  0.084909
# 2      log-likelihood  0.000000  39.890701  2.0  2.176930e-09  0.084175
# 3       freeman-tukey -0.500000  39.437100  2.0  2.731131e-09  0.083695
# 4  mod-log-likelihood -1.000000  39.041138  2.0  3.329082e-09  0.083274
# 5              neyman -2.000000  38.412219  2.0  4.559241e-09  0.082600
#
#       power
# 0  0.999977
# 1  0.999974
# 2  0.999967
# 3  0.999962
# 4  0.999957
# 5  0.999947
# Reject null hypothesis: There is a statistically significant difference between CityTier and Churn
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#                  test    lambda       chi2  dof          pval    cramer  \
# 0             pearson  1.000000  51.828960  4.0  1.497857e-10  0.095947
# 1        cressie-read  0.666667  50.675428  4.0  2.609448e-10  0.094873
# 2      log-likelihood  0.000000  48.629681  4.0  6.975479e-10  0.092939
# 3       freeman-tukey -0.500000  47.301963  4.0  1.319299e-09  0.091661
# 4  mod-log-likelihood -1.000000  46.132875  4.0  2.310922e-09  0.090521
# 5              neyman -2.000000  44.214686  4.0  5.789658e-09  0.088619
#
#       power
# 0  0.999995
# 1  0.999993
# 2  0.999987
# 3  0.999981
# 4  0.999973
# 5  0.999951
# Reject null hypothesis: There is a statistically significant difference between PreferredPaymentMode and Churn
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#                  test    lambda      chi2  dof      pval    cramer     power
# 0             pearson  1.000000  4.662908  1.0  0.030821  0.028779  0.579049
# 1        cressie-read  0.666667  4.674527  1.0  0.030613  0.028815  0.580100
# 2      log-likelihood  0.000000  4.698851  1.0  0.030183  0.028890  0.582294
# 3       freeman-tukey -0.500000  4.718062  1.0  0.029847  0.028949  0.584021
# 4  mod-log-likelihood -1.000000  4.738117  1.0  0.029501  0.029010  0.585819
# 5              neyman -2.000000  4.780818  1.0  0.028778  0.029140  0.589628
# Reject null hypothesis: There is a statistically significant difference between Gender and Churn
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#                  test    lambda        chi2  dof          pval    cramer  \
# 0             pearson  1.000000  288.597786  4.0  3.119243e-61  0.226408
# 1        cressie-read  0.666667  288.222723  4.0  3.757789e-61  0.226261
# 2      log-likelihood  0.000000  292.883258  4.0  3.713888e-62  0.228083
# 3       freeman-tukey -0.500000  301.931953  4.0  4.150074e-64  0.231580
# 4  mod-log-likelihood -1.000000  317.004134  4.0  2.323771e-67  0.237289
# 5              neyman -2.000000  373.553716  4.0  1.437088e-79  0.257586
#
#    power
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# 5    1.0
# Reject null hypothesis: There is a statistically significant difference between PreferedOrderCat and Churn
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#                  test    lambda        chi2  dof          pval    cramer  \
# 0             pearson  1.000000  188.671040  2.0  1.073011e-41  0.183062
# 1        cressie-read  0.666667  185.156674  2.0  6.219267e-41  0.181349
# 2      log-likelihood  0.000000  179.833020  2.0  8.907501e-40  0.178723
# 3       freeman-tukey -0.500000  177.221959  2.0  3.286552e-39  0.177421
# 4  mod-log-likelihood -1.000000  175.715803  2.0  6.979081e-39  0.176665
# 5              neyman -2.000000  175.842068  2.0  6.552095e-39  0.176729
#
#    power
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# 5    1.0
# Reject null hypothesis: There is a statistically significant difference between MaritalStatus and Churn
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#                  test    lambda        chi2  dof          pval    cramer  \
# 0             pearson  1.000000  350.925455  1.0  2.664461e-78  0.249662
# 1        cressie-read  0.666667  339.298174  1.0  9.072277e-76  0.245492
# 2      log-likelihood  0.000000  321.869085  1.0  5.672542e-72  0.239103
# 3       freeman-tukey -0.500000  313.232587  1.0  4.315578e-70  0.235874
# 4  mod-log-likelihood -1.000000  307.920529  1.0  6.197668e-69  0.233865
# 5              neyman -2.000000  306.144268  1.0  1.510729e-68  0.233189
#
#    power
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# 5    1.0
# Reject null hypothesis: There is a statistically significant difference between Complain and Churn
# --------------------------------------------------------------------------------

# %%
for col in num_features:
    hypothesis_testing.kruskal_wallis_test(df, 'Churn', col, sig_col=sig_cols, no_sig_col=no_sig_cols)
# Out:
# --------------------------------------------------------------------------------
#         Source  ddof1           H          p-unc
# Kruskal  Churn      1  878.092864  5.678503e-193
# Reject null hypothesis: There is a statistically significant difference in Tenure between Churn.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#         Source  ddof1          H         p-unc
# Kruskal  Churn      1  35.406192  2.676347e-09
# Reject null hypothesis: There is a statistically significant difference in WarehouseToHome between Churn.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#         Source  ddof1         H    p-unc
# Kruskal  Churn      1  1.460878  0.22679
# Failed to reject null hypothesis: There is no statistically significant difference in HourSpendOnApp between Churn
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#         Source  ddof1          H         p-unc
# Kruskal  Churn      1  57.699428  3.053916e-14
# Reject null hypothesis: There is a statistically significant difference in NumberOfDeviceRegistered between Churn.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#         Source  ddof1          H         p-unc
# Kruskal  Churn      1  61.826091  3.751701e-15
# Reject null hypothesis: There is a statistically significant difference in SatisfactionScore between Churn.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#         Source  ddof1        H     p-unc
# Kruskal  Churn      1  4.68109  0.030496
# Reject null hypothesis: There is a statistically significant difference in NumberOfAddress between Churn.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#         Source  ddof1        H     p-unc
# Kruskal  Churn      1  2.29431  0.129849
# Failed to reject null hypothesis: There is no statistically significant difference in OrderAmountHikeFromlastYear between Churn
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#         Source  ddof1         H     p-unc
# Kruskal  Churn      1  1.230046  0.267398
# Failed to reject null hypothesis: There is no statistically significant difference in CouponUsed between Churn
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#         Source  ddof1         H     p-unc
# Kruskal  Churn      1  4.379986  0.036363
# Reject null hypothesis: There is a statistically significant difference in OrderCount between Churn.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#         Source  ddof1           H         p-unc
# Kruskal  Churn      1  185.565082  2.954178e-42
# Reject null hypothesis: There is a statistically significant difference in DaySinceLastOrder between Churn.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#         Source  ddof1           H         p-unc
# Kruskal  Churn      1  167.564739  2.518104e-38
# Reject null hypothesis: There is a statistically significant difference in CashbackAmount between Churn.
# --------------------------------------------------------------------------------

# %%
print(f"Significant columns: {sig_cols}")
print(f"No significant columns: {no_sig_cols}")
# Out:
# Significant columns: ['PreferredLoginDevice', 'CityTier', 'PreferredPaymentMode', 'Gender', 'PreferedOrderCat', 'MaritalStatus', 'Complain', 'Tenure', 'WarehouseToHome', 'NumberOfDeviceRegistered', 'SatisfactionScore', 'NumberOfAddress', 'OrderCount', 'DaySinceLastOrder', 'CashbackAmount']
# No significant columns: ['HourSpendOnApp', 'OrderAmountHikeFromlastYear', 'CouponUsed']
